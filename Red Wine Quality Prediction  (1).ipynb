# %% [markdown]
# # Red Wine Quality Prediction Project

# %%
# Step -1 Import all Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Step-2 Importing Red Wine dataset

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [raw]
# # This dataset is having total 1599 rows of data and 12 columns in which 11 are input variable and 1 output variable(Dependant variable). Now we need to predict the which variables are mostly effecting the quality of wine. The dataset is having numeric data and the dataset is termed as Classification problem (Binary Classifiaction)

# %%
#Step-3 Perform EDA - Exploratory Data Analysis

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [raw]
# #In this dataset, there are 2 types of datatypes, i.e., float64 and int 64

# %%
# Checking for any Empty spaces or Null values

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# The above info gives that this dataset is not having any null values

# %%
# We will use Heatmap to visualize the Null values in the dataset

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# The above map shows clearly that there are no null values in the given dataset

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# ...

# %% [markdown]
# The above data clearly shows the value counts of each column. We can also find the unique values and number of unique values in each column using unique and nuinque function.

# %%
df['fixed acidity'].unique()
# Out:
# array([ 7.4,  7.8, 11.2,  7.9,  7.3,  7.5,  6.7,  5.6,  8.9,  8.5,  8.1,
#         7.6,  6.9,  6.3,  7.1,  8.3,  5.2,  5.7,  8.8,  6.8,  4.6,  7.7,
#         8.7,  6.4,  6.6,  8.6, 10.2,  7. ,  7.2,  9.3,  8. ,  9.7,  6.2,
#         5. ,  4.7,  8.4, 10.1,  9.4,  9. ,  8.2,  6.1,  5.8,  9.2, 11.5,
#         5.4,  9.6, 12.8, 11. , 11.6, 12. , 15. , 10.8, 11.1, 10. , 12.5,
#        11.8, 10.9, 10.3, 11.4,  9.9, 10.4, 13.3, 10.6,  9.8, 13.4, 10.7,
#        11.9, 12.4, 12.2, 13.8,  9.1, 13.5, 10.5, 12.6, 14. , 13.7,  9.5,
#        12.7, 12.3, 15.6,  5.3, 11.3, 13. ,  6.5, 12.9, 14.3, 15.5, 11.7,
#        13.2, 15.9, 12.1,  5.1,  4.9,  5.9,  6. ,  5.5])

# %%
df['fixed acidity'].nunique()
# Out:
# 96

# %%
df['volatile acidity'].unique()
# Out:
# array([0.7  , 0.88 , 0.76 , 0.28 , 0.66 , 0.6  , 0.65 , 0.58 , 0.5  ,
#        0.615, 0.61 , 0.62 , 0.56 , 0.59 , 0.32 , 0.22 , 0.39 , 0.43 ,
#        0.49 , 0.4  , 0.41 , 0.71 , 0.645, 0.675, 0.685, 0.655, 0.605,
#        0.38 , 1.13 , 0.45 , 0.67 , 0.52 , 0.935, 0.29 , 0.31 , 0.51 ,
#        0.42 , 0.63 , 0.69 , 0.735, 0.725, 0.705, 0.785, 0.75 , 0.625,
#        0.3  , 0.55 , 1.02 , 0.775, 0.9  , 0.545, 0.575, 0.33 , 0.54 ,
#        1.07 , 0.695, 1.33 , 0.745, 1.04 , 0.715, 0.415, 0.34 , 0.68 ,
#        0.95 , 0.53 , 0.64 , 0.885, 0.805, 0.73 , 0.37 , 0.835, 1.09 ,
#        0.57 , 0.44 , 0.635, 0.82 , 0.48 , 1.   , 0.21 , 0.35 , 0.975,
#        0.26 , 0.87 , 0.18 , 0.27 , 0.2  , 0.36 , 0.83 , 0.46 , 0.47 ,
#        0.77 , 0.815, 0.795, 0.665, 0.765, 0.24 , 0.85 , 0.84 , 0.96 ,
#        0.78 , 0.23 , 0.315, 0.365, 0.25 , 0.825, 0.72 , 0.595, 0.585,
#        0.915, 0.755, 0.845, 1.24 , 0.8  , 0.98 , 1.185, 0.92 , 1.035,
# ...

# %%
df['volatile acidity'].nunique()
# Out:
# 143

# %%
df['citric acid'].unique()
# Out:
# array([0.  , 0.04, 0.56, 0.06, 0.02, 0.36, 0.08, 0.29, 0.18, 0.19, 0.28,
#        0.51, 0.48, 0.31, 0.21, 0.11, 0.14, 0.16, 0.24, 0.07, 0.12, 0.25,
#        0.09, 0.3 , 0.2 , 0.22, 0.15, 0.43, 0.52, 0.23, 0.37, 0.26, 0.57,
#        0.4 , 0.49, 0.05, 0.54, 0.64, 0.7 , 0.47, 0.44, 0.17, 0.68, 0.53,
#        0.1 , 0.01, 0.55, 1.  , 0.03, 0.42, 0.33, 0.32, 0.35, 0.6 , 0.74,
#        0.58, 0.5 , 0.76, 0.46, 0.45, 0.38, 0.39, 0.66, 0.62, 0.67, 0.79,
#        0.63, 0.61, 0.71, 0.65, 0.59, 0.34, 0.69, 0.73, 0.72, 0.41, 0.27,
#        0.75, 0.13, 0.78])

# %%
df['citric acid'].nunique()
# Out:
# 80

# %%
df['residual sugar'].unique()
# Out:
# array([ 1.9 ,  2.6 ,  2.3 ,  1.8 ,  1.6 ,  1.2 ,  2.  ,  6.1 ,  3.8 ,
#         3.9 ,  1.7 ,  4.4 ,  2.4 ,  1.4 ,  2.5 , 10.7 ,  5.5 ,  2.1 ,
#         1.5 ,  5.9 ,  2.8 ,  2.2 ,  3.  ,  3.4 ,  5.1 ,  4.65,  1.3 ,
#         7.3 ,  7.2 ,  2.9 ,  2.7 ,  5.6 ,  3.1 ,  3.2 ,  3.3 ,  3.6 ,
#         4.  ,  7.  ,  6.4 ,  3.5 , 11.  ,  3.65,  4.5 ,  4.8 ,  2.95,
#         5.8 ,  6.2 ,  4.2 ,  7.9 ,  3.7 ,  6.7 ,  6.6 ,  2.15,  5.2 ,
#         2.55, 15.5 ,  4.1 ,  8.3 ,  6.55,  4.6 ,  4.3 ,  5.15,  6.3 ,
#         6.  ,  8.6 ,  7.5 ,  2.25,  4.25,  2.85,  3.45,  2.35,  2.65,
#         9.  ,  8.8 ,  5.  ,  1.65,  2.05,  0.9 ,  8.9 ,  8.1 ,  4.7 ,
#         1.75,  7.8 , 12.9 , 13.4 ,  5.4 , 15.4 ,  3.75, 13.8 ,  5.7 ,
#        13.9 ])

# %%
df['residual sugar'].nunique()
# Out:
# 91

# %%
df['chlorides'].unique()
# Out:
# array([0.076, 0.098, 0.092, 0.075, 0.069, 0.065, 0.073, 0.071, 0.097,
#        0.089, 0.114, 0.176, 0.17 , 0.368, 0.086, 0.341, 0.077, 0.082,
#        0.106, 0.084, 0.085, 0.08 , 0.105, 0.083, 0.103, 0.066, 0.172,
#        0.074, 0.088, 0.332, 0.05 , 0.054, 0.113, 0.068, 0.081, 0.11 ,
#        0.07 , 0.111, 0.079, 0.115, 0.094, 0.093, 0.104, 0.464, 0.401,
#        0.062, 0.107, 0.045, 0.058, 0.102, 0.467, 0.091, 0.122, 0.09 ,
#        0.119, 0.178, 0.146, 0.072, 0.118, 0.049, 0.06 , 0.117, 0.087,
#        0.236, 0.61 , 0.095, 0.1  , 0.36 , 0.067, 0.27 , 0.099, 0.046,
#        0.061, 0.056, 0.039, 0.059, 0.101, 0.057, 0.337, 0.078, 0.263,
#        0.063, 0.611, 0.064, 0.096, 0.358, 0.343, 0.186, 0.112, 0.213,
#        0.214, 0.121, 0.128, 0.052, 0.12 , 0.116, 0.109, 0.159, 0.124,
#        0.174, 0.047, 0.127, 0.413, 0.152, 0.053, 0.055, 0.051, 0.125,
#        0.2  , 0.171, 0.226, 0.25 , 0.108, 0.148, 0.143, 0.222, 0.157,
# ...

# %%
df['chlorides'].nunique()
# Out:
# 153

# %% [markdown]
# In the same way, we can find value counts of unique values for all the columns.We can use above either of the way to know value counts. The above data shows that there is no blank spaces in any column.

# %%
#Step -4, Description of Columns Data

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [raw]
# The above description shows the important information of each columns as mentioned below
#
# 1. The mean value is greater than Median(i.e., 50%) in all the columns except density and quality(Target variable) column, that means the graph of data will be right skewed.Whereas the mean in density and quality column is less than Median(50%) which tells us the graph is left skewed.
# 2. The count of all the columns is same which means there are no missing values in any columns.
# 3. In some of the columns (such as residual sugar, free sulfur dioxide, total sulfur dioxide) there is a huge difference between max column and 75% which means there may be chances of outliers in the data.

# %%
#Step -5 , Data Visualization

# %% [raw]
# Here we need to use plot graphs to see how all the features effecting quality of wine. lets plot a bar plot for each feature with quality to visualize how its effecting.

# %%
plt.figure(figsize=[6,2])
plt.bar(df['quality'],df['fixed acidity'],color ='m')
plt.xlabel('quality')
plt.ylabel('fixed acidity')
# Out:
# Text(0, 0.5, 'fixed acidity')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['volatile acidity'],color='m')
plt.xlabel('quality')
plt.ylabel('volatile acidity')
# Out:
# Text(0, 0.5, 'volatile acidity')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['citric acid'],color='m')
plt.xlabel('quality')
plt.ylabel('citric acid')
# Out:
# Text(0, 0.5, 'citric acid')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['residual sugar'],color='m')
plt.xlabel('quality')
plt.ylabel('residual sugar')
# Out:
# Text(0, 0.5, 'residual sugar')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['chlorides'],color='m')
plt.xlabel('quality')
plt.ylabel('chlorides')
# Out:
# Text(0, 0.5, 'chlorides')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['free sulfur dioxide'],color='m')
plt.xlabel('quality')
plt.ylabel('free sulfur dioxide')
# Out:
# Text(0, 0.5, 'free sulfur dioxide')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['total sulfur dioxide'],color='m')
plt.xlabel('quality')
plt.ylabel('total sulfur dioxide')
# Out:
# Text(0, 0.5, 'total sulfur dioxide')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['density'],color='m')
plt.xlabel('quality')
plt.ylabel('density')
# Out:
# Text(0, 0.5, 'density')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['pH'],color='m')
plt.xlabel('quality')
plt.ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['sulphates'],color='m')
plt.xlabel('quality')
plt.ylabel('sulphates')
# Out:
# Text(0, 0.5, 'sulphates')

# %%
plt.figure(figsize=[8,4])
plt.bar(df['quality'],df['alcohol'],color='m')
plt.xlabel('quality')
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %% [markdown]
# From the above images we can clearly see how each feature is performing and their counts in an easy understandable way.

# %% [markdown]
# We can plot histogram to see the graphical representation and how each feature is effective and comparision.

# %%
df.hist(bins=30,figsize=(10,10))
plt.show()

# %% [raw]
# The above graphs reveals how the features are distributed.

# %%
plt.figure(figsize=[8,4])
df['fixed acidity'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['volatile acidity'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['citric acid'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['residual sugar'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['chlorides'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['free sulfur dioxide'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['total sulfur dioxide'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['density'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['pH'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['sulphates'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['alcohol'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=[8,4])
df['quality'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# The above density curve is a smooth curve which shows how the data is distributed in a one single line.It gives more clear understanding of features.

# %% [raw]
# We need to remove unwanted columns which is not much affecting to study the data.We need to remove the columns where data is highly correlated. To do that we need to find correlation in data using heatmap.

# %% [raw]
# step -6 : Finding Correlation of data

# %%
plt.figure(figsize=[15,10])

sns.heatmap(df.corr(),annot =True)
plt.show()

# %% [raw]
# As the correlation in all the rows are below 0.7, that means moderately correlated.If the Correlation is above 0.7, it is highly correlated.As it is not highly correlated, I am not dropping any columns and I further proceed with the developing the model

# %%
df['best quality'] = [1 if x >=7 else 0 for x in df.quality]

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head(30)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %% [raw]
# #Here we have made all the rows with quality into two categories as per the problem. i.e., quality >=7 as 1 and < 7 as 0

# %%
df.tail(30)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1569            6.2             0.510         0.14             1.9      0.056
# 1570            6.4             0.360         0.53             2.2      0.230
# 1571            6.4             0.380         0.14             2.2      0.038
# 1572            7.3             0.690         0.32             2.2      0.069
# 1573            6.0             0.580         0.20             2.4      0.075
# 1574            5.6             0.310         0.78            13.9      0.074
# 1575            7.5             0.520         0.40             2.2      0.060
# 1576            8.0             0.300         0.63             1.6      0.081
# 1577            6.2             0.700         0.15             5.1      0.076
# 1578            6.8             0.670         0.15             1.8      0.118
# 1579            6.2             0.560         0.09             1.7      0.053
# ...

# %%
#Step-7, Checking for outlier:

# %%
sns.boxplot(y='fixed acidity', data = df)
# Out:
# <Axes: ylabel='fixed acidity'>

# %%
Here we can see outliers are present in fixed acidity column.

# %%
sns.boxplot(y='volatile acidity', data = df)
# Out:
# <Axes: ylabel='volatile acidity'>

# %%
sns.boxplot(y='citric acid', data = df)
# Out:
# <Axes: ylabel='citric acid'>

# %%
sns.boxplot(y='residual sugar', data = df)
# Out:
# <Axes: ylabel='residual sugar'>

# %%
sns.boxplot(y='chlorides', data = df)
# Out:
# <Axes: ylabel='chlorides'>

# %%
sns.boxplot(y='free sulfur dioxide', data = df)
# Out:
# <Axes: ylabel='free sulfur dioxide'>

# %%
sns.boxplot(y='total sulfur dioxide', data = df)
# Out:
# <Axes: ylabel='total sulfur dioxide'>

# %%
sns.boxplot(y='density', data = df)
# Out:
# <Axes: ylabel='density'>

# %%
sns.boxplot(y='pH', data = df)
# Out:
# <Axes: ylabel='pH'>

# %%
sns.boxplot(y='sulphates', data = df)
# Out:
# <Axes: ylabel='sulphates'>

# %%
sns.boxplot(y='alcohol', data = df)
# Out:
# <Axes: ylabel='alcohol'>

# %%
sns.boxplot(y='best quality', data = df)
# Out:
# <Axes: ylabel='best quality'>

# %%
#As we can see in the plots, almost all the columns are having outliers.We have remove the outliers using zscore and IQR techniques before building the model.

# %%
from scipy.stats import zscore

out_features = df[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','best quality']]
z = np.abs(zscore(out_features))
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
# ...

# %%
np.where(z>3)
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          467,  480,  480,  494,  515,  544,  554,  554,  555,  555,  557,
#          557,  568,  584,  588,  591,  595,  608,  614,  636,  639,  649,
#          649,  651,  652,  652,  652,  672,  672,  684,  690,  692,  692,
#          695,  723,  724,  730,  754,  776,  777,  795,  821,  836,  837,
#          889,  911,  917,  923,  925,  926,  982, 1017, 1018, 1043, 1051,
#         1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154,
#         1165, 1175, 1186, 1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269,
# ...

# %%
df1 = df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (1458, 13)

# %%
print("First DataFrame -", df.shape[0])
print("New DataFrame -", df1.shape[0])
# Out:
# First DataFrame - 1599
# New DataFrame - 1458

# %%
print("Data Loss percentage -",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss percentage - 8.818011257035648

# %%
df=df1

# %%
#The loss of data is less than 10% and it is affordable. So, now we can check with IQR method

# %%
#1st Quantile
Q1 = out_features.quantile(0.25)

#3RD Quantile
Q3 = out_features.quantile(0.75)

#IQR
IQR = Q3 -Q1
df2 = df[~((df<(Q1 -1.5 *IQR))|(df>(Q3 + 1.5 * IQR))).any(axis =1)]

# %%
df2.shape
# Out:
# (1047, 13)

# %%
print (" Data Loss percentage after removing outliers with IQR method -", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
#  Data Loss percentage after removing outliers with IQR method - 28.189300411522634

# %% [raw]
# As the data loss is 28% and which is too high and we cannot afford to remove that.So, I will go ahead with z score method.

# %%
#After removing outliers we need to check how the data is distributed of columns

df.hist(bins=20,figsize=(10,10))
plt.show()

# %%
#Checking skewness values

df.skew()
# Out:
# fixed acidity           0.820879
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          2.450707
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# quality                 0.248823
# best quality            2.103030
# dtype: float64

# %% [raw]
# As the skewness is between -3 to +3 there is no need to remove skewness from the data.

# %%
#Step -8, Now lets Split the data using Train and Test method

# %% [raw]
# We have to split the data and perform training and testing in 80:20 ration

# %%
#importing library 
from sklearn.model_selection import train_test_split

# %%
features = df.drop(['quality', 'best quality'], axis=1)
target = df['best quality']
 
xtrain, xtest, ytrain, ytest = train_test_split(features, target, test_size=0.2, random_state=40)
 
xtrain.shape, xtest.shape
# Out:
# ((1166, 11), (292, 11))

# %% [raw]
# Here features comes under x - axis and target is y-axis.After the training the data , we need to normalize the data to before testing to get a best training and fit of data

# %%
# Step -8, Normalization of data

# %%
#importing library
from sklearn.preprocessing import MinMaxScaler

# %%
#Creating an Object for Normalization

norm = MinMaxScaler()

# %%
xtrain = norm.fit_transform(xtrain)
xtest = norm.transform(xtest)

# %%
print(xtrain)
# Out:
# [[0.76470588 0.32608696 0.60759494 ... 0.24137931 0.24096386 0.5       ]
#  [0.24705882 0.52173913 0.01265823 ... 0.59770115 0.3373494  0.48076923]
#  [0.44705882 0.35869565 0.5443038  ... 0.37931034 0.5060241  0.34615385]
#  ...
#  [0.27058824 0.57608696 0.         ... 0.5862069  0.1686747  0.30769231]
#  [0.35294118 0.48913043 0.29113924 ... 0.43678161 0.28915663 0.17307692]
#  [0.23529412 0.58152174 0.20253165 ... 0.56321839 0.26506024 0.25      ]]

# %%
print(xtest)
# Out:
# [[0.18823529 0.41304348 0.05063291 ... 0.5862069  0.37349398 0.19230769]
#  [0.24705882 0.51086957 0.         ... 0.62068966 0.42168675 0.46153846]
#  [0.24705882 0.60869565 0.         ... 0.65517241 0.24096386 0.21153846]
#  ...
#  [0.97647059 0.23913043 0.65822785 ... 0.1954023  0.57831325 0.21153846]
#  [0.35294118 0.35869565 0.29113924 ... 0.37931034 0.19277108 0.34615385]
#  [0.16470588 0.47826087 0.18987342 ... 0.51724138 0.3253012  0.40384615]]

# %%
xtrain.shape
# Out:
# (1166, 11)

# %%
xtest.shape
# Out:
# (292, 11)

# %%
#Step - 9, Applying Model - To check the best accuracy value in the data.

# %% [raw]
# Here we can try the different models in Machine Learning to see the best accuracy score.

# %%
# Firstly we need to import required libraries

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
RFC = RandomForestClassifier()
RFC.fit(xtrain,ytrain)
print('calculating the error')
PredRFC = RFC. predict(xtest)
print(accuracy_score(ytest,PredRFC))
print(confusion_matrix(ytest, PredRFC))
print(classification_report(ytest, PredRFC))
# Out:
# calculating the error
# 0.9417808219178082
# [[248   6]
#  [ 11  27]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       254
#            1       0.82      0.71      0.76        38
#
#     accuracy                           0.94       292
#    macro avg       0.89      0.84      0.86       292
# weighted avg       0.94      0.94      0.94       292

# %% [raw]
# Accuracy score using RandomForest Classifier is 94.17%

# %%
LR = LogisticRegression()
LR.fit(xtrain,ytrain)
print('calculating the error')
PredLR = LR. predict(xtest)
print(accuracy_score(ytest,PredLR))
print(confusion_matrix(ytest, PredLR))
print(classification_report(ytest, PredLR))
# Out:
# calculating the error
# 0.9075342465753424
# [[251   3]
#  [ 24  14]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       254
#            1       0.82      0.37      0.51        38
#
#     accuracy                           0.91       292
#    macro avg       0.87      0.68      0.73       292
# weighted avg       0.90      0.91      0.89       292

# %% [raw]
# Accuracy score using Logistic Regression is 90.75%

# %%
GBR = GradientBoostingClassifier()
GBR.fit(xtrain,ytrain)
print('calculating the error')
PredGBR = GBR. predict(xtest)
print(accuracy_score(ytest,PredGBR))
print(confusion_matrix(ytest, PredGBR))
print(classification_report(ytest, PredGBR))
# Out:
# calculating the error
# 0.9212328767123288
# [[243  11]
#  [ 12  26]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       254
#            1       0.70      0.68      0.69        38
#
#     accuracy                           0.92       292
#    macro avg       0.83      0.82      0.82       292
# weighted avg       0.92      0.92      0.92       292

# %% [raw]
# Accuracy score value using GradientBoostingClassifier is 92.12%

# %%
ADB = AdaBoostClassifier()
ADB.fit(xtrain,ytrain)
print('calculating the error')
PredADB = ADB. predict(xtest)
print(accuracy_score(ytest,PredADB))
print(confusion_matrix(ytest, PredADB))
print(classification_report(ytest, PredADB))
# Out:
# calculating the error
# 0.9041095890410958
# [[242  12]
#  [ 16  22]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       254
#            1       0.65      0.58      0.61        38
#
#     accuracy                           0.90       292
#    macro avg       0.79      0.77      0.78       292
# weighted avg       0.90      0.90      0.90       292

# %% [raw]
# Accuracy score using AdaBoost Classifier is 90.41%

# %% [raw]
# # The above all the models tell us that Random Forest Classifier gives the best accuracy value of 91.56% and second comes Gradient Boosting classifier. There is not much difference between RFC and GBC.

# %%
#As the Random Forest Classifier gives the best accuracy score. We will differentiate the actual and  the Predicted values

x_predict = list(RFC.predict(xtest))
Predicted_df = {'Predicted_values': x_predict, 'Actual_values': ytest}
pd.DataFrame(Predicted_df).head(30)
# Out:
#       Predicted_values  Actual_values
# 52                   0              0
# 1171                 0              0
# 1550                 0              0
# 1311                 0              0
# 61                   0              0
# 498                  1              1
# 993                  0              0
# 1487                 0              0
# 173                  0              0
# 1315                 0              0
# 638                  0              1
# 790                  0              0
# 812                  0              0
# 1011                 0              0
# 1208                 1              1
# 1301                 0              0
# 1077                 0              0
# 133                  0              0
# 1317                 0              0
# 1450                 1              1
# 1262                 0              0
# 427                  0              0
# 525                  0              0
# 249                  0              0
# ...

# %%
#Step -10, Hyper Parameter Tuning

# %%
svc_param = {'kernel' : ['poly', 'sigmoid', 'rbf'],
             'gamma' : ['scale', 'auto'],
             'shrinking' : [True, False],
             'random_state' : [21,42,104],
             'probability' : [True, False],
             'decision_function_shape' : ['ovo', 'ovr'],
             'verbose' : [True, False]}

# %%
GSCV = GridSearchCV(SVC(), svc_param, cv=5)

# %%
# Step - 11 , Saving the Model

# %%
import pickle

# %%
file = 'Red_Wine_Quality_Prediction'
save = pickle.dump(RFC,open(file,'wb'))
